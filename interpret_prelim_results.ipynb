# %%
import pandas as pd
import numpy as np

# %%
file_name = 'results_cross_fold.csv'

# %%
res = pd.read_csv(file_name, index_col='Metadataset')
# res.drop('Unnamed: 0', axis=1, inplace=True) #TODO: havent rerun the code in get_prelim_results.csv to get rid of this
res.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of                               RandomForest  LogisticRegression       SVC  \
# Metadataset
# info-theory_metadataset.csv       0.393548            0.372910  0.386703
# relative_metadataset.csv          0.419139            0.324806  0.386982
# general_metadataset.csv           0.423302            0.368391  0.407341
# complexity_metadataset.csv        0.396698            0.240679  0.371914
# default_metadataset.csv           0.368538            0.255921  0.396177
# d2v_pretrained_metadaset.csv      0.368417            0.336442  0.372989
# concept_metadataset.csv           0.354127            0.315397  0.366508
# model-based_metadataset.csv       0.365368            0.250438  0.406524
# clustering_metadataset.csv        0.390123            0.364323  0.383119
# landmarking_metadataset.csv       0.393852            0.396177  0.393852
# statistical_metadataset.csv       0.386677            0.253605  0.368312
# itemset_metadataset.csv           0.298119            0.382837  0.387461
# all_metadataset.csv               0.385601            0.228291  0.373259
#
#                               KNeighbors  GaussianNB  DecisionTree  AdaBoost  \
# Metadataset
# info-theory_metadataset.csv     0.237957    0.228736      0.260763  0.279363
# relative_metadataset.csv        0.230313    0.320155      0.297300  0.387142
# general_metadataset.csv         0.279023    0.173929      0.347884  0.233203
# complexity_metadataset.csv      0.322778    0.210895      0.327562  0.376728
# default_metadataset.csv         0.299599    0.232906      0.329564  0.294894
# d2v_pretrained_metadaset.csv    0.286181    0.146317      0.292921  0.208072
# concept_metadataset.csv         0.315873    0.321270      0.247937  0.354444
# model-based_metadataset.csv     0.283674    0.199643      0.291594  0.250276
# clustering_metadataset.csv      0.277975    0.170807      0.303639  0.298632
# landmarking_metadataset.csv     0.313312    0.329431      0.304036  0.382358
# statistical_metadataset.csv     0.240125    0.249086      0.311155  0.336494
# itemset_metadataset.csv         0.284431    0.305303      0.277508  0.266040
# all_metadataset.csv             0.258196    0.240728      0.328259  0.295791
#
#                               GradientBoosting       MLP   Bagging  \
# Metadataset
# info-theory_metadataset.csv           0.338715  0.373041  0.352586
# relative_metadataset.csv              0.318043  0.386955  0.262684
# general_metadataset.csv               0.290648  0.386677  0.324896
# complexity_metadataset.csv            0.377099  0.364506  0.369599
# default_metadataset.csv               0.310960  0.145202  0.405426
# d2v_pretrained_metadaset.csv          0.306609  0.164342  0.295324
# concept_metadataset.csv               0.231270  0.393810  0.304762
# model-based_metadataset.csv           0.240084  0.176339  0.321973
# clustering_metadataset.csv            0.305992  0.380739  0.324651
# landmarking_metadataset.csv           0.343090  0.331783  0.354718
# statistical_metadataset.csv           0.327247  0.230852  0.315961
# itemset_metadataset.csv               0.295794  0.385162  0.289054
# all_metadataset.csv                   0.293228  0.155506  0.368323
#
#                               ExtraTrees    Voting
# Metadataset
# info-theory_metadataset.csv     0.361546  0.396055
# relative_metadataset.csv        0.322534  0.377760
# general_metadataset.csv         0.377691  0.391353
# complexity_metadataset.csv      0.426667  0.441389
# default_metadataset.csv         0.440070  0.426223
# d2v_pretrained_metadaset.csv    0.288454  0.329519
# concept_metadataset.csv         0.337937  0.360317
# model-based_metadataset.csv     0.367997  0.342454
# clustering_metadataset.csv      0.371436  0.399398
# landmarking_metadataset.csv     0.373029  0.412296
# statistical_metadataset.csv     0.372962  0.382132
# itemset_metadataset.csv         0.293574  0.355564
# all_metadataset.csv             0.393418  0.373259  >

# %%
# get the max probaility for each metadataset and the associated ml algorithm that gave the best accuracy
max_name = res.idxmax(axis=1)
# get the max probability for each metadataset
max_prob = res.max(axis=1)
max_prob
# Out:
# Metadataset
# info-theory_metadataset.csv     0.396055
# relative_metadataset.csv        0.419139
# general_metadataset.csv         0.423302
# complexity_metadataset.csv      0.441389
# default_metadataset.csv         0.440070
# d2v_pretrained_metadaset.csv    0.372989
# concept_metadataset.csv         0.393810
# model-based_metadataset.csv     0.406524
# clustering_metadataset.csv      0.399398
# landmarking_metadataset.csv     0.412296
# statistical_metadataset.csv     0.386677
# itemset_metadataset.csv         0.387461
# all_metadataset.csv             0.393418
# dtype: float64

# %%
max_name.str.split('_').str[0]
# Out:
# Metadataset
# info-theory_metadataset.csv           Voting
# relative_metadataset.csv        RandomForest
# general_metadataset.csv         RandomForest
# complexity_metadataset.csv            Voting
# default_metadataset.csv           ExtraTrees
# d2v_pretrained_metadaset.csv             SVC
# concept_metadataset.csv                  MLP
# model-based_metadataset.csv              SVC
# clustering_metadataset.csv            Voting
# landmarking_metadataset.csv           Voting
# statistical_metadataset.csv     RandomForest
# itemset_metadataset.csv                  SVC
# all_metadataset.csv               ExtraTrees
# dtype: object

# %%
max_name = max_name.str.split('_').str[0]
results = pd.DataFrame({'ML Algorithm': max_name, 'Max Probability': max_prob})
# split index column names after the _
results.index = results.index.str.split('_').str[0]
# append pymfe to all row indexes except d2v
results.index = results.index.map(lambda x: 'd2v' if x == 'd2v' else f'pymfe_{x}')
results
# Out:
#                    ML Algorithm  Max Probability
# Metadataset
# pymfe_info-theory        Voting         0.396055
# pymfe_relative     RandomForest         0.419139
# pymfe_general      RandomForest         0.423302
# pymfe_complexity         Voting         0.441389
# pymfe_default        ExtraTrees         0.440070
# d2v                         SVC         0.372989
# pymfe_concept               MLP         0.393810
# pymfe_model-based           SVC         0.406524
# pymfe_clustering         Voting         0.399398
# pymfe_landmarking        Voting         0.412296
# pymfe_statistical  RandomForest         0.386677
# pymfe_itemset               SVC         0.387461
# pymfe_all            ExtraTrees         0.393418

# %%
# just grab the rows for genearl, stastistical, info_theory and d2v
small = results.loc[['pymfe_general', 'pymfe_statistical', 'pymfe_info-theory', 'd2v']]
# drop the ML Algorithm column
small.drop('ML Algorithm', axis=1, inplace=True)

# %%
small
# Out:
#                    Max Probability
# Metadataset
# pymfe_general             0.423302
# pymfe_statistical         0.386677
# pymfe_info-theory         0.396055
# d2v                       0.372989

# %%
# calculate max of each row
res_max = res.max().sort_values(ascending=False).to_frame()
res_max = res_max.reset_index()
res_max.columns = ['Metadataset', 'Max_Accuracy']
res_max
# Out:
#            Metadataset  Max_Accuracy
# 0               Voting      0.441389
# 1           ExtraTrees      0.440070
# 2         RandomForest      0.423302
# 3                  SVC      0.407341
# 4              Bagging      0.405426
# 5   LogisticRegression      0.396177
# 6                  MLP      0.393810
# 7             AdaBoost      0.387142
# 8     GradientBoosting      0.377099
# 9         DecisionTree      0.347884
# 10          GaussianNB      0.329431
# 11          KNeighbors      0.322778

# %%
# general
# info-thory 
# statistical 
# all of these didnt fail on any of the datasets so run it on these too
# get the max probably for those three datasets and the algorihtm that performed best
